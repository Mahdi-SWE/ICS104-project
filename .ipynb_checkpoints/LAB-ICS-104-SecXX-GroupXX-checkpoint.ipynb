# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------
#
#                                Done By: Ibrahim Nemer (inemer@kfupm.edu.sa)
#
# ---------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------

# %%
sectionNumber = "80"
groupNumber = ""
studentName1 = "Mahdi alkhawajha"
studentNameID1 = "201867860"
stdContribution1 = ""
studentName2 = ""
studentNameID2 = ""
stdContribution2 = ""

# %% [markdown]
# # Title
# Enter the title of your project here.
#
# ## Purpose
# Describe the objective of your project here.
#
# ## Methodology
# Describe your methodology in details here including: pseudo code, assumptions and processing steps.
#
# ## Improvements
# Show how you divided your project into stages and the required time for each stage, as follows:
# - Stage ONE: Function 1, Function 2  and I achieved it within one day/hour.
# - Stage TWO: ...................
# - Stage THREE: ...................
# - ...........
#
# ## Results
# Describe and comment the most important results for each stage as images (insert your image and describe it briefly).
#
# ## Remaining stages
# State the remaining stages (if you have); state your thoughts for these stages and why you didn't achieve them.

# %% [markdown]
# # Setup
#
# ## Local library import
# We import all the required Python libraries in the following cell only.

# %%
# libraries and modules based on the permitted list on the description of the project
import sys

# %% [markdown]
# ## Other library import
# We import also another libraries which are not from the permitted list. Here, you are required to comment why you add them and if you got approval from your lab instructor or NOT.

# %%
# Include other libraries
import time

# %% [markdown]
# # Functions
# Put your functions including the main function after this line in code-cells, add cells as the number of functions.

# %%
def create():
    x=True
    while x:                    #the need for while loop is to repeat if the user enter a letters or
                                #numbers with letters for card numberor PIN
        
        try:                    #try function will Classify if the input all digit or not
        
            cardnumber=int(input("Enter a 4 digit numbers for new card number: (it should be not repeated numbers) ")) 
                                #here the user will enter his card number
        
            #this loop will check if the card number is 4 digit
            while not len(str(cardnumber))==4: 
                    print("wrong input, you should enter 4 digits try again")   
                    cardnumber=int(input())
                    
            
            
            while True:        #this loop will check if there any repeat number in the card number
                
                cardnumber=str(cardnumber)   #if statment will check every digit with the other
                if cardnumber[0]==cardnumber[1]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())
                elif cardnumber[0]==cardnumber[2]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())    
                elif cardnumber[0]==cardnumber[3]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())                                         
                elif cardnumber[1]==cardnumber[2]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())    
                elif cardnumber[1]==cardnumber[3]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())
                elif cardnumber[2]==cardnumber[3]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())    
                else:
                    break 
                    
                    
                    
                
            PIN=int(input("Enter a 4 digit numbers for your PIN: (it should be not repeated numbers) "))
            
            
            while not len(str(PIN))==4:    #this loop will check if the PIN is 4 digit
                    print("wrong input, you should enter 4 digits try again")   
                    PIN=int(input())
                    
            
            
            
            while True:        #this loop will check if there any repeat number in the PIN
                
                PIN=str(PIN)   #if statment will check every digit with the other
                if PIN[0]==PIN[1]:
                    print("wrong input, you should not repeat any number try again")
                    PIN=int(input())
                elif PIN[0]==PIN[2]:
                    print("wrong input, you should not repeat any number try again")
                    PIN=int(input())    
                elif PIN[0]==PIN[3]:
                    print("wrong input, you should not repeat any number try again")
                    PIN=int(input())                                                 
                elif PIN[1]==PIN[2]:
                    print("wrong input, you should not repeat any number try again")
                    PIN=int(input())    
                elif PIN[1]==PIN[3]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input()) 
                elif cardnumber[2]==cardnumber[3]:
                    print("wrong input, you should not repeat any number try again")
                    cardnumber=int(input())     
                else:
                    
                    x=False    #this x to break the big while in the beginning
                    
                    break
                    
                    
                    
                
            
        except ValueError:
            print("wrong input, you should only enter digits try again")
            
    
    email=input("enter your KFUPM email: ")
    
    while True:                            #this loop will keep run unril the user enter a correct email
        
        if not "@kfupm.edu.sa" in email:   #this will check if its KFUPM email
            
            print("you should enter your KFUPM email, try again")
            email=input()
        elif not email[0:3]=='g20':        #this will check if the email start with the ID
            
            print("you should enter your KFUPM email, try again")
            email=input()
        else:
            break
    
    extra_services=input("would you like to have extra services? (yes or no) ")
    extra_services=extra_services.upper()
    if extra_services=='YES':
        answer=input("do you want to active Online payment? (yes or no) ")
        answer=answer.upper()
        if answer=='YES':
            service='the Online payment is active'
        else:
            service=''
        another=input("do you want another service? (yes or no) ")
        another=another.upper()
    if extra_services=='NO' or another=='YES':
        another_service=input("Do you want an initial deposit? (yes or no) ")
        another_service=another_service.upper()
        if another_service=='YES':
            service2=float(input("how much will you deposit? "))
        else:
            service2=''
        
    file=open(cardnumber+".txt","w")     #a file will be create with same card number after the user enter everything correctly
    file.write(cardnumber+"\n")
    file.write(PIN+"\n")                   #all the information that was entered by the user will be written in the file 
    file.write(email+"\n")
    file.write(service+"\n")
    file.write(str(service2)+"\n")
    file.close()

# %%
def menu():                                #this function is created to call the menu instead of write it every time
    print()
    print("Bank acount program")
    print("="*33)
    print("1.  Show acount information")
    print("2.  Change PIN number")
    print("3.  withdraw amount of money")
    print("4.  Deposit amount of money")
    print("5.  Pay bills")
    print("6.  View the last transaction")
    print("7.  Terminate a program")
    print("="*33)

# %%
def login():
    
    
    y=True
    while y:                                #the try function will check if the user enter an exist account by his card number 
        
        try:
        
            cardnumber=input("enter your card number ")
            file=open(cardnumber+".txt","r")               #his file will be open to handle the information inside it
            PIN=int(input("Enter your PIN "))
            line=file.readline()
            line=file.readline()                           #here the program will skip line which is contain the card number
            line=line.strip("\n")                          
            line=int(line)
            while True:                                    #the while loop will keep runing if the user 
                if PIN==line:                              #enter wrong PIN which will be checked in the if statment
                    menu()
                    break
                else:
                    print("Wrong PIN, check your PIN and try again")
                    PIN=int(input())
            
            y=False
        except FileNotFoundError:
            print("this card number is not exist, check your card number and try again")
    return int(cardnumber), PIN                           #the function will return the card number and PIN to be treated in 
                                                          #the menu which will be showed after the user enter to his account

# %%
def show(file):
    cardnumber=str(file)
    file=open(cardnumber+".txt","r")                      #user's file will be opened after he choose show account information
    line=file.readline()
    while line!='':
        line=line.strip()                                 #in this loop every line in the file will be read and printed to let 
        print(line)                                       #the user see the details
        line=file.readline()
        
        
    file.close()
    time.sleep(3)

# %%
def changePINFun(currentPIN, cardNumber, file):
    File=open(str(file)+'.txt','r')                      #user's file will be opeded to change his PIN
    line=File.readline() 
    List=[]                                              #this list is to save user's information
    while line !='':
        line=line.strip()
        List.append(line)                                #while loop will read and save the information in the list
        line=File.readline()
    
    x=True
    while x:                                             #try and while function will check if the new PIN is acceptable or not
        try:
            new_PIN=int(input("Enter your new PIN "))
            while not len(str(new_PIN))==4: 
                    print("wrong input, you should enter 4 digits try again")   
                    new_PIN=int(input())
            x=False
        except ValueError:
            print("wrong input, you should only enter digits try again")
            
    List.pop(1)                                          #after the user enter correct new PIN the function will delete
    List.insert(1,new_PIN)                               #the old one and change it with the new one in the list that 
    new_file=open(str(cardNumber)+'.txt','w')            #was created earlier
    for i in List:
        new_file.write(str(i)+'\n')                      #this loop will write the information in the list into the user's 
                                                         #file because open function with mood write will delete everything
    new_file.close()

# %%
answer=input("Enter 'L' or for log in or Enter 'S' or for sign up: ") # here the user will choose which operation he wants

while True:                        # the while loop will keep ask the user to choose 
    
    if answer.isalpha(): # it will check if the user's choice right choice or not
        answer=answer.upper()
        while answer=="S":            #it will call the create function
            create()
            print()
            answer=input("Enter 'L' or for log in or Enter 'S' or for sign up: ")
        if answer=="L":            #it will call the create function
            cardnumber,PIN=login()
            break 
    else:
        print("wrong choice")
        answer=input("Enter L or for log in or Enter S or for sign up: ")

try:
    feature=int(input("Enter your feature: "))
    
    x=True
    while x:
        if feature==1:
            show(cardnumber)
    
        if feature==2:
            changePINFun(PIN,cardnumber,cardnumber)
            
                        
        menu()
        feature=int(input("Enter your feature: "))
        
except ValueError:
    print("you should choose a number, try again")
    feature=int(input())
# Out:
#   File "<ipython-input-48-bd1357f8f052>", line 21
#     while :
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Test Cases
# Put here two test cases, you can insert them as images.

# %% [markdown]
# # References
# Report here the relevant references (journals, books, websites):
# 1. author1, article1, journal1, year1, url1
# 2. author2, article2, journal2, year2, url2
